# %% [markdown]
# # Data visualisation task

# %% [markdown]
# **Additional information**
# [Cars93 metadata](https://jse.amstat.org/v1n1/datasets.lock.html)

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Load data
car_data = pd.read_csv('Cars93.csv', keep_default_na=False)
car_data.sample(5)
# Out:
#     Unnamed: 0 Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 35          36         Ford  Aerostar      Van       14.5   19.9       25.3
# 80          81       Subaru    Loyale    Small       10.5   10.9       11.3
# 11          12    Chevrolet  Cavalier  Compact        8.5   13.4       18.3
# 44          45      Hyundai   Elantra    Small        9.0   10.0       11.0
# 8            9        Buick   Riviera  Midsize       26.3   26.3       26.3
#
#     MPG.city  MPG.highway      AirBags  ... Passengers Length  Wheelbase  \
# 35        15           20  Driver only  ...          7    176        119
# 80        25           30         None  ...          5    175         97
# 11        25           36         None  ...          5    182        101
# 44        22           29         None  ...          5    172         98
# 8         19           27  Driver only  ...          5    198        108
#
# ...

# %%
car_data.columns
# Out:
# Index(['Unnamed: 0', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             93 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
# ...

# %% [markdown]
# ### 1. Boxplot

# %%
# Boxplot for revs per mile
plt.figure(figsize=(20, 20))
sns.boxplot(car_data, x='RPM', y='Manufacturer')
plt.ylabel('Manufacturer')
plt.xlabel('Revs per mile (RPM)')
plt.show()

# %% [markdown]
# **Boxplot question:**
# Which of these manufacturers has the car with the highest revs per mile?

# %% [markdown]
# **Boxplot answer:**
# Mazda have the highest revs per mile as its whisker to the right is the longest at about 6500rpm

# %% [markdown]
# ### 2. Histogram

# %%
# Histogram of MPG
car_data_MPG = pd.DataFrame({'highway': car_data['MPG.highway'], 'city': car_data['MPG.city']})
sns.histplot(car_data_MPG)
plt.xlabel('Miles per gallon (MPG)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Histogram question:**
# Is it generally more fuel efficient to drive in the city or on the highway?

# %% [markdown]
# **Histogram answer:**
# Generally, drives in highway are more fuel efficient, the highest bar for the highway mile per gallon is to the right of that of the city. which shows most vehicles on the highway cover more miles per gallon than most in the city.

# %% [markdown]
# ### 3. Lineplot

# %%
# Lineplot (Wheelbase vs turning circle)
plt.figure(figsize=(20, 10))
sns.lineplot(car_data, x='Wheelbase', y='Turn.circle')
plt.xlabel('Wheel base')
plt.ylabel('Turning circle')
plt.show()

# %% [markdown]
# **Lineplot question:**
# What is this relationship? What happens when the wheelbase gets larger?

# %% [markdown]
# **Lineplot answer:**
# The lineplot shows a positive trend, which shows that the larger the wheelbase, the higher the turning circle gets. At around 110 wheelbase, it can be noticed that the turning circle remains constant.

# %% [markdown]
# ### 4. Barplot

# %%
# Barplot for mean horsepower

sns.barplot(car_data, x='Type', y='Horsepower')
plt.xlabel('Car type')
plt.ylabel('Average horse power')
plt.show()

# %% [markdown]
# **Barplot question:**
# Does a larger car mean more horsepower?

# %% [markdown]
# **Barplot answer:**
# from the barplot, it can be deducted that larger cars tend to have more horsepower on average

# %%
car_data['Area'] = car_data['Width'] * car_data['Length']
car_data['Area']
# Out:
# 0     12036
# 1     13845
# 2     12060
# 3     13510
# 4     12834
#       ...
# 88    13464
# 89    12060
# 90    10494
# 91    12730
# 92    12696
# Name: Area, Length: 93, dtype: int64
