# %%
from sklearn.datasets import load_diabetes
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = load_diabetes(as_frame=True).data[['s1', 's2']]
df
# Out:
#            s1        s2
# 0   -0.044223 -0.034821
# 1   -0.008449 -0.019163
# 2   -0.045599 -0.034194
# 3    0.012191  0.024991
# 4    0.003935  0.015596
# ..        ...       ...
# 437 -0.005697 -0.002566
# 438  0.049341  0.079165
# 439 -0.037344 -0.013840
# 440  0.016318  0.015283
# 441  0.083740  0.027809
#
# [442 rows x 2 columns]

# %%
plt.figure()
sns.scatterplot(data=df, x='s1', y='s2', palette='hsl', marker='x')
plt.show()
plt.close()
# Out:
# /tmp/ipykernel_8418/782547742.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, x='s1', y='s2', palette='hsl', marker='x')

# %%
df.corr()
# Out:
#           s1        s2
# s1  1.000000  0.896663
# s2  0.896663  1.000000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
linear_reg = LinearRegression()

# %%
x = df.drop('s2', axis=1).to_numpy()
# x = df['s1'].values.reshape((-1, 1))
# x.shape

y = df['s2'].to_numpy().reshape((-1, 1))
y.shape
# Out:
# (442, 1)

# %%
tts = train_test_split(x, y, test_size=0.15)
x_train, x_test, y_train, y_test = tts

# %%
linear_reg.fit(x_train, y_train)
y_pred = linear_reg.predict(x_test)
# y_pred

# %%
plt.figure()
sns.scatterplot(data=df, x='s1', y='s2')
plt.plot(x_test, y_pred)
# plt.plot(y_test, color='red')
plt.show()
plt.close()
